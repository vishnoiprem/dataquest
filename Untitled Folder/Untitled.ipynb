# %%
import requests
response = requests.get("http://api.open-notify.org/iss-now.json")
print(response)
status_code=response.status_code
# Out:
# <Response [200]>

# %%
status_code
# Out:
# 200

# %%
# Enter your answer below.

response=requests.get('http://api.open-notify.org/iss-pass')
status_code=response.status_code

# %%
response
# Out:
# <Response [404]>

# %%
# Set up the parameters we want to pass to the API.
# This is the latitude and longitude of New York City.
parameters = {"lat": 40.71, "lon": -74}

# Make a get request with the parameters.
response = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)

# Print the content of the response (the data the server returned)
print(response.content)
parameters = {"lat": 37.78 , "lon": -122.41}


# This gets the same data as the command above
response = requests.get("http://api.open-notify.org/iss-pass.json",params=parameters)
content=response.content
# Out:
# b'{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1559746135, \n    "latitude": 40.71, \n    "longitude": -74.0, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 480, \n      "risetime": 1559753827\n    }, \n    {\n      "duration": 645, \n      "risetime": 1559759512\n    }, \n    {\n      "duration": 600, \n      "risetime": 1559765354\n    }, \n    {\n      "duration": 553, \n      "risetime": 1559771236\n    }, \n    {\n      "duration": 608, \n      "risetime": 1559777066\n    }\n  ]\n}\n'

# %%
response.content
# Out:
# b'{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1559749554, \n    "latitude": 37.78, \n    "longitude": -122.41, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 506, \n      "risetime": 1559764900\n    }, \n    {\n      "duration": 645, \n      "risetime": 1559770603\n    }, \n    {\n      "duration": 561, \n      "risetime": 1559776474\n    }, \n    {\n      "duration": 479, \n      "risetime": 1559782389\n    }, \n    {\n      "duration": 559, \n      "risetime": 1559788224\n    }\n  ]\n}\n'

# %%
# Make a list of fast food chains.
best_food_chains = ["Taco Bell", "Shake Shack", "Chipotle"]
print(type(best_food_chains))

# Import the JSON library.
import json

# Use json.dumps to convert best_food_chains to a string.
best_food_chains_string = json.dumps(best_food_chains)
print(type(best_food_chains_string))

# Convert best_food_chains_string back to a list.
print(type(json.loads(best_food_chains_string)))

# Make a dictionary
fast_food_franchise = {
    "Subway": 24722,
    "McDonalds": 14098,
    "Starbucks": 10821,
    "Pizza Hut": 7600
}

# We can also dump a dictionary to a string and load it.
fast_food_franchise_string = json.dumps(fast_food_franchise)
print(type(fast_food_franchise_string))
# Out:
# <class 'list'>
# <class 'str'>
# <class 'list'>
# <class 'str'>

# %%
json.dumps(['a','b'])
# Out:
# '["a", "b"]'

# %%
json.loads(json.dumps(['a','b']))
# Out:
# ['a', 'b']

# %%
# Make the same request we did two screens ago.
parameters = {"lat": 37.78, "lon": -122.41}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)

# Get the response data as a Python object.  Verify that it's a dictionary.
json_data = response.json()
print(type(json_data))
print(json_data)

first_pass_duration=json_data['response'][0]['duration']
# Out:
# <class 'dict'>
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1559749554, 'latitude': 37.78, 'longitude': -122.41, 'passes': 5}, 'response': [{'duration': 506, 'risetime': 1559764900}, {'duration': 645, 'risetime': 1559770603}, {'duration': 561, 'risetime': 1559776474}, {'duration': 479, 'risetime': 1559782389}, {'duration': 559, 'risetime': 1559788224}]}

# %%
# Headers is a dictionary
print(response.headers)

content_type=response.headers['content-type']
# Out:
# {'Server': 'nginx/1.10.3', 'Date': 'Wed, 05 Jun 2019 15:51:27 GMT', 'Content-Type': 'application/json', 'Content-Length': '521', 'Connection': 'keep-alive', 'Via': '1.1 vegur'}

# %%
content_type
# Out:
# 'application/json'

# %%
# Create a dictionary of headers containing our Authorization header.
headers = {"Authorization": "token b0943db47bd2c1e08678206409e30f8b55e18dee"}

# Make a GET request to the GitHub API with our headers.
# This API endpoint will give us details about Vik Paruchuri.
response = requests.get("https://api.github.com/users/vishnoiprem", headers=headers)

# Print the content of the response.  As you can see, this token corresponds to the account of Vik Paruchuri.
print(response.json())
# Out:
# {'login': 'vishnoiprem', 'id': 5586954, 'node_id': 'MDQ6VXNlcjU1ODY5NTQ=', 'avatar_url': 'https://avatars2.githubusercontent.com/u/5586954?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/vishnoiprem', 'html_url': 'https://github.com/vishnoiprem', 'followers_url': 'https://api.github.com/users/vishnoiprem/followers', 'following_url': 'https://api.github.com/users/vishnoiprem/following{/other_user}', 'gists_url': 'https://api.github.com/users/vishnoiprem/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/vishnoiprem/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/vishnoiprem/subscriptions', 'organizations_url': 'https://api.github.com/users/vishnoiprem/orgs', 'repos_url': 'https://api.github.com/users/vishnoiprem/repos', 'events_url': 'https://api.github.com/users/vishnoiprem/events{/privacy}', 'received_events_url': 'https://api.github.com/users/vishnoiprem/received_events', 'type': 'User', 'site_admin': False, 'name': 'vishnoiprem', 'company': None, 'blog': '', 'location': None, 'email': None, 'hireable': True, 'bio': None, 'public_repos': 17, 'public_gists': 1, 'followers': 0, 'following': 3, 'created_at': '2013-10-01T15:27:46Z', 'updated_at': '2019-06-05T15:58:33Z', 'private_gists': 9, 'total_private_repos': 0, 'owned_private_repos': 0, 'disk_usage': 40101, 'collaborators': 0, 'two_factor_authentication': False, 'plan': {'name': 'free', 'space': 976562499, 'collaborators': 0, 'private_repos': 10000}}

# %%
# Create a dictionary of headers containing our Authorization header.
headers = {"Authorization": "token b0943db47bd2c1e08678206409e30f8b55e18dee"}

# Make a GET request to the GitHub API with our headers.
# This API endpoint will give us details about Vik Paruchuri.
response = requests.get("https://api.github.com/users/vishnoiprem", headers=headers)

# Print the content of the response.  As you can see, this token corresponds to the account of Vik Paruchuri.
print(response.json())
# Out:
# {'login': 'vishnoiprem', 'id': 5586954, 'node_id': 'MDQ6VXNlcjU1ODY5NTQ=', 'avatar_url': 'https://avatars2.githubusercontent.com/u/5586954?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/vishnoiprem', 'html_url': 'https://github.com/vishnoiprem', 'followers_url': 'https://api.github.com/users/vishnoiprem/followers', 'following_url': 'https://api.github.com/users/vishnoiprem/following{/other_user}', 'gists_url': 'https://api.github.com/users/vishnoiprem/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/vishnoiprem/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/vishnoiprem/subscriptions', 'organizations_url': 'https://api.github.com/users/vishnoiprem/orgs', 'repos_url': 'https://api.github.com/users/vishnoiprem/repos', 'events_url': 'https://api.github.com/users/vishnoiprem/events{/privacy}', 'received_events_url': 'https://api.github.com/users/vishnoiprem/received_events', 'type': 'User', 'site_admin': False, 'name': 'vishnoiprem', 'company': None, 'blog': '', 'location': None, 'email': None, 'hireable': True, 'bio': None, 'public_repos': 17, 'public_gists': 1, 'followers': 0, 'following': 3, 'created_at': '2013-10-01T15:27:46Z', 'updated_at': '2019-06-05T15:58:33Z', 'private_gists': 9, 'total_private_repos': 0, 'owned_private_repos': 0, 'disk_usage': 40101, 'collaborators': 0, 'two_factor_authentication': False, 'plan': {'name': 'free', 'space': 976562499, 'collaborators': 0, 'private_repos': 10000}}

# %%
response = requests.get("https://api.github.com/users/torvalds", headers=headers)
torvalds = response.json()

# %%
torvalds
# Out:
# {'login': 'torvalds',
#  'id': 1024025,
#  'node_id': 'MDQ6VXNlcjEwMjQwMjU=',
#  'avatar_url': 'https://avatars0.githubusercontent.com/u/1024025?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/torvalds',
#  'html_url': 'https://github.com/torvalds',
#  'followers_url': 'https://api.github.com/users/torvalds/followers',
#  'following_url': 'https://api.github.com/users/torvalds/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions',
#  'organizations_url': 'https://api.github.com/users/torvalds/orgs',
#  'repos_url': 'https://api.github.com/users/torvalds/repos',
#  'events_url': 'https://api.github.com/users/torvalds/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/torvalds/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'Linus Torvalds',
#  'company': 'Linux Foundation',
#  'blog': '',
#  'location': 'Portland, OR',
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'public_repos': 6,
#  'public_gists': 0,
#  'followers': 94808,
#  'following': 0,
#  'created_at': '2011-09-03T15:26:22Z',
#  'updated_at': '2019-04-14T21:28:58Z'}

# %%
response = requests.get("https://api.github.com/repos/octocat/Hello-World", headers=headers)

hello_world=response.json()

# %%
hello_world
# Out:
# {'id': 1296269,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxMjk2MjY5',
#  'name': 'Hello-World',
#  'full_name': 'octocat/Hello-World',
#  'private': False,
#  'owner': {'login': 'octocat',
#   'id': 583231,
#   'node_id': 'MDQ6VXNlcjU4MzIzMQ==',
#   'avatar_url': 'https://avatars3.githubusercontent.com/u/583231?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/octocat',
#   'html_url': 'https://github.com/octocat',
#   'followers_url': 'https://api.github.com/users/octocat/followers',
#   'following_url': 'https://api.github.com/users/octocat/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/octocat/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/octocat/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/octocat/subscriptions',
#   'organizations_url': 'https://api.github.com/users/octocat/orgs',
#   'repos_url': 'https://api.github.com/users/octocat/repos',
#   'events_url': 'https://api.github.com/users/octocat/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/octocat/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/octocat/Hello-World',
#  'description': 'My first repository on GitHub!',
#  'fork': False,
#  'url': 'https://api.github.com/repos/octocat/Hello-World',
#  'forks_url': 'https://api.github.com/repos/octocat/Hello-World/forks',
#  'keys_url': 'https://api.github.com/repos/octocat/Hello-World/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/octocat/Hello-World/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/octocat/Hello-World/teams',
#  'hooks_url': 'https://api.github.com/repos/octocat/Hello-World/hooks',
#  'issue_events_url': 'https://api.github.com/repos/octocat/Hello-World/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/octocat/Hello-World/events',
#  'assignees_url': 'https://api.github.com/repos/octocat/Hello-World/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/octocat/Hello-World/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/octocat/Hello-World/tags',
#  'blobs_url': 'https://api.github.com/repos/octocat/Hello-World/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/octocat/Hello-World/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/octocat/Hello-World/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/octocat/Hello-World/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/octocat/Hello-World/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/octocat/Hello-World/languages',
#  'stargazers_url': 'https://api.github.com/repos/octocat/Hello-World/stargazers',
#  'contributors_url': 'https://api.github.com/repos/octocat/Hello-World/contributors',
#  'subscribers_url': 'https://api.github.com/repos/octocat/Hello-World/subscribers',
#  'subscription_url': 'https://api.github.com/repos/octocat/Hello-World/subscription',
#  'commits_url': 'https://api.github.com/repos/octocat/Hello-World/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/octocat/Hello-World/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/octocat/Hello-World/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/octocat/Hello-World/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/octocat/Hello-World/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/octocat/Hello-World/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/octocat/Hello-World/merges',
#  'archive_url': 'https://api.github.com/repos/octocat/Hello-World/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/octocat/Hello-World/downloads',
#  'issues_url': 'https://api.github.com/repos/octocat/Hello-World/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/octocat/Hello-World/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/octocat/Hello-World/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/octocat/Hello-World/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/octocat/Hello-World/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/octocat/Hello-World/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/octocat/Hello-World/deployments',
#  'created_at': '2011-01-26T19:01:12Z',
#  'updated_at': '2019-06-05T10:42:19Z',
#  'pushed_at': '2019-05-28T07:14:39Z',
#  'git_url': 'git://github.com/octocat/Hello-World.git',
#  'ssh_url': 'git@github.com:octocat/Hello-World.git',
#  'clone_url': 'https://github.com/octocat/Hello-World.git',
#  'svn_url': 'https://github.com/octocat/Hello-World',
#  'homepage': '',
#  'size': 1,
#  'stargazers_count': 1485,
#  'watchers_count': 1485,
#  'language': None,
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'forks_count': 1332,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 346,
#  'license': None,
#  'forks': 1332,
#  'open_issues': 346,
#  'watchers': 1485,
#  'default_branch': 'master',
#  'permissions': {'admin': False, 'push': False, 'pull': True},
#  'network_count': 1332,
#  'subscribers_count': 1638}

# %%
params = {"per_page": 50, "page": 1}
response = requests.get("https://api.github.com/users/VikParuchuri/starred", headers=headers, params=params)
page1_repos = response.json()

params = {"per_page": 50, "page": 2}
response = requests.get("https://api.github.com/users/VikParuchuri/starred", headers=headers, params=params)
page2_repos = response.json()

# %%
page2_repos
# Out:
# [{'id': 22553797,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjU1Mzc5Nw==',
#   'name': 'grav',
#   'full_name': 'getgrav/grav',
#   'private': False,
#   'owner': {'login': 'getgrav',
#    'id': 8237355,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgyMzczNTU=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8237355?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/getgrav',
#    'html_url': 'https://github.com/getgrav',
#    'followers_url': 'https://api.github.com/users/getgrav/followers',
#    'following_url': 'https://api.github.com/users/getgrav/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/getgrav/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/getgrav/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/getgrav/subscriptions',
#    'organizations_url': 'https://api.github.com/users/getgrav/orgs',
#    'repos_url': 'https://api.github.com/users/getgrav/repos',
#    'events_url': 'https://api.github.com/users/getgrav/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/getgrav/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/getgrav/grav',
#   'description': 'Modern, Crazy Fast, Ridiculously Easy and Amazingly Powerful Flat-File CMS',
#   'fork': False,
#   'url': 'https://api.github.com/repos/getgrav/grav',
#   'forks_url': 'https://api.github.com/repos/getgrav/grav/forks',
#   'keys_url': 'https://api.github.com/repos/getgrav/grav/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/getgrav/grav/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/getgrav/grav/teams',
#   'hooks_url': 'https://api.github.com/repos/getgrav/grav/hooks',
#   'issue_events_url': 'https://api.github.com/repos/getgrav/grav/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/getgrav/grav/events',
#   'assignees_url': 'https://api.github.com/repos/getgrav/grav/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/getgrav/grav/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/getgrav/grav/tags',
#   'blobs_url': 'https://api.github.com/repos/getgrav/grav/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/getgrav/grav/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/getgrav/grav/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/getgrav/grav/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/getgrav/grav/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/getgrav/grav/languages',
#   'stargazers_url': 'https://api.github.com/repos/getgrav/grav/stargazers',
#   'contributors_url': 'https://api.github.com/repos/getgrav/grav/contributors',
#   'subscribers_url': 'https://api.github.com/repos/getgrav/grav/subscribers',
#   'subscription_url': 'https://api.github.com/repos/getgrav/grav/subscription',
#   'commits_url': 'https://api.github.com/repos/getgrav/grav/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/getgrav/grav/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/getgrav/grav/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/getgrav/grav/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/getgrav/grav/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/getgrav/grav/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/getgrav/grav/merges',
#   'archive_url': 'https://api.github.com/repos/getgrav/grav/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/getgrav/grav/downloads',
#   'issues_url': 'https://api.github.com/repos/getgrav/grav/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/getgrav/grav/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/getgrav/grav/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/getgrav/grav/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/getgrav/grav/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/getgrav/grav/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/getgrav/grav/deployments',
#   'created_at': '2014-08-02T18:29:10Z',
#   'updated_at': '2019-06-05T14:11:50Z',
#   'pushed_at': '2019-06-05T02:13:21Z',
#   'git_url': 'git://github.com/getgrav/grav.git',
#   'ssh_url': 'git@github.com:getgrav/grav.git',
#   'clone_url': 'https://github.com/getgrav/grav.git',
#   'svn_url': 'https://github.com/getgrav/grav',
#   'homepage': 'https://getgrav.org',
#   'size': 16116,
#   'stargazers_count': 11021,
#   'watchers_count': 11021,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1105,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 340,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 1105,
#   'open_issues': 340,
#   'watchers': 11021,
#   'default_branch': 'develop',
#   'permissions': {'admin': False, 'push': False, 'pull': True}},
#  {'id': 29514104,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTUxNDEwNA==',
#   'name': 'netlify-cms',
#   'full_name': 'netlify/netlify-cms',
#   'private': False,
#   'owner': {'login': 'netlify',
#    'id': 7892489,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc4OTI0ODk=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/7892489?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/netlify',
#    'html_url': 'https://github.com/netlify',
#    'followers_url': 'https://api.github.com/users/netlify/followers',
#    'following_url': 'https://api.github.com/users/netlify/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/netlify/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/netlify/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/netlify/subscriptions',
#    'organizations_url': 'https://api.github.com/users/netlify/orgs',
#    'repos_url': 'https://api.github.com/users/netlify/repos',
#    'events_url': 'https://api.github.com/users/netlify/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/netlify/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/netlify/netlify-cms',
#   'description': 'A CMS for Static Site Generators',
#   'fork': False,
#   'url': 'https://api.github.com/repos/netlify/netlify-cms',
#   'forks_url': 'https://api.github.com/repos/netlify/netlify-cms/forks',
#   'keys_url': 'https://api.github.com/repos/netlify/netlify-cms/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/netlify/netlify-cms/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/netlify/netlify-cms/teams',
#   'hooks_url': 'https://api.github.com/repos/netlify/netlify-cms/hooks',
#   'issue_events_url': 'https://api.github.com/repos/netlify/netlify-cms/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/netlify/netlify-cms/events',
#   'assignees_url': 'https://api.github.com/repos/netlify/netlify-cms/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/netlify/netlify-cms/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/netlify/netlify-cms/tags',
#   'blobs_url': 'https://api.github.com/repos/netlify/netlify-cms/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/netlify/netlify-cms/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/netlify/netlify-cms/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/netlify/netlify-cms/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/netlify/netlify-cms/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/netlify/netlify-cms/languages',
#   'stargazers_url': 'https://api.github.com/repos/netlify/netlify-cms/stargazers',
#   'contributors_url': 'https://api.github.com/repos/netlify/netlify-cms/contributors',
#   'subscribers_url': 'https://api.github.com/repos/netlify/netlify-cms/subscribers',
#   'subscription_url': 'https://api.github.com/repos/netlify/netlify-cms/subscription',
#   'commits_url': 'https://api.github.com/repos/netlify/netlify-cms/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/netlify/netlify-cms/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/netlify/netlify-cms/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/netlify/netlify-cms/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/netlify/netlify-cms/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/netlify/netlify-cms/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/netlify/netlify-cms/merges',
#   'archive_url': 'https://api.github.com/repos/netlify/netlify-cms/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/netlify/netlify-cms/downloads',
#   'issues_url': 'https://api.github.com/repos/netlify/netlify-cms/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/netlify/netlify-cms/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/netlify/netlify-cms/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/netlify/netlify-cms/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/netlify/netlify-cms/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/netlify/netlify-cms/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/netlify/netlify-cms/deployments',
#   'created_at': '2015-01-20T05:47:47Z',
#   'updated_at': '2019-06-05T16:13:21Z',
#   'pushed_at': '2019-06-04T18:08:17Z',
#   'git_url': 'git://github.com/netlify/netlify-cms.git',
#   'ssh_url': 'git@github.com:netlify/netlify-cms.git',
#   'clone_url': 'https://github.com/netlify/netlify-cms.git',
#   'svn_url': 'https://github.com/netlify/netlify-cms',
#   'homepage': 'https://www.netlifycms.org',
#   'size': 27293,
#   'stargazers_count': 8743,
#   'watchers_count': 8743,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1224,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 444,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 1224,
#   'open_issues': 444,
#   'watchers': 8743,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True}},
#  {'id': 13147353,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMzE0NzM1Mw==',
#   'name': 'sl4a',
#   'full_name': 'damonkohler/sl4a',
#   'private': False,
#   'owner': {'login': 'damonkohler',
#    'id': 191389,
#    'node_id': 'MDQ6VXNlcjE5MTM4OQ==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/191389?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/damonkohler',
#    'html_url': 'https://github.com/damonkohler',
#    'followers_url': 'https://api.github.com/users/damonkohler/followers',
#    'following_url': 'https://api.github.com/users/damonkohler/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/damonkohler/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/damonkohler/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/damonkohler/subscriptions',
#    'organizations_url': 'https://api.github.com/users/damonkohler/orgs',
#    'repos_url': 'https://api.github.com/users/damonkohler/repos',
#    'events_url': 'https://api.github.com/users/damonkohler/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/damonkohler/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/damonkohler/sl4a',
#   'description': 'SL4A brings scripting languages to Android by allowing you to edit and execute scripts and interactive interpreters directly on the Android device.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/damonkohler/sl4a',
#   'forks_url': 'https://api.github.com/repos/damonkohler/sl4a/forks',
#   'keys_url': 'https://api.github.com/repos/damonkohler/sl4a/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/damonkohler/sl4a/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/damonkohler/sl4a/teams',
#   'hooks_url': 'https://api.github.com/repos/damonkohler/sl4a/hooks',
#   'issue_events_url': 'https://api.github.com/repos/damonkohler/sl4a/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/damonkohler/sl4a/events',
#   'assignees_url': 'https://api.github.com/repos/damonkohler/sl4a/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/damonkohler/sl4a/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/damonkohler/sl4a/tags',
#   'blobs_url': 'https://api.github.com/repos/damonkohler/sl4a/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/damonkohler/sl4a/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/damonkohler/sl4a/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/damonkohler/sl4a/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/damonkohler/sl4a/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/damonkohler/sl4a/languages',
#   'stargazers_url': 'https://api.github.com/repos/damonkohler/sl4a/stargazers',
#   'contributors_url': 'https://api.github.com/repos/damonkohler/sl4a/contributors',
#   'subscribers_url': 'https://api.github.com/repos/damonkohler/sl4a/subscribers',
#   'subscription_url': 'https://api.github.com/repos/damonkohler/sl4a/subscription',
#   'commits_url': 'https://api.github.com/repos/damonkohler/sl4a/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/damonkohler/sl4a/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/damonkohler/sl4a/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/damonkohler/sl4a/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/damonkohler/sl4a/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/damonkohler/sl4a/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/damonkohler/sl4a/merges',
#   'archive_url': 'https://api.github.com/repos/damonkohler/sl4a/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/damonkohler/sl4a/downloads',
#   'issues_url': 'https://api.github.com/repos/damonkohler/sl4a/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/damonkohler/sl4a/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/damonkohler/sl4a/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/damonkohler/sl4a/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/damonkohler/sl4a/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/damonkohler/sl4a/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/damonkohler/sl4a/deployments',
#   'created_at': '2013-09-27T10:11:09Z',
#   'updated_at': '2019-06-05T06:46:28Z',
#   'pushed_at': '2018-10-27T17:22:30Z',
#   'git_url': 'git://github.com/damonkohler/sl4a.git',
#   'ssh_url': 'git@github.com:damonkohler/sl4a.git',
#   'clone_url': 'https://github.com/damonkohler/sl4a.git',
#   'svn_url': 'https://github.com/damonkohler/sl4a',
#   'homepage': '',
#   'size': 309568,
#   'stargazers_count': 1916,
#   'watchers_count': 1916,
#   'language': 'C',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 704,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 311,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 704,
#   'open_issues': 311,
#   'watchers': 1916,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True}},
#  {'id': 36040894,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjA0MDg5NA==',
#   'name': 'gatsby',
#   'full_name': 'gatsbyjs/gatsby',
#   'private': False,
#   'owner': {'login': 'gatsbyjs',
#    'id': 12551863,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyNTUxODYz',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/12551863?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gatsbyjs',
#    'html_url': 'https://github.com/gatsbyjs',
#    'followers_url': 'https://api.github.com/users/gatsbyjs/followers',
#    'following_url': 'https://api.github.com/users/gatsbyjs/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gatsbyjs/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gatsbyjs/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gatsbyjs/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gatsbyjs/orgs',
#    'repos_url': 'https://api.github.com/users/gatsbyjs/repos',
#    'events_url': 'https://api.github.com/users/gatsbyjs/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gatsbyjs/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/gatsbyjs/gatsby',
#   'description': 'Build blazing fast, modern apps and websites with React',
#   'fork': False,
#   'url': 'https://api.github.com/repos/gatsbyjs/gatsby',
#   'forks_url': 'https://api.github.com/repos/gatsbyjs/gatsby/forks',
#   'keys_url': 'https://api.github.com/repos/gatsbyjs/gatsby/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/gatsbyjs/gatsby/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/gatsbyjs/gatsby/teams',
#   'hooks_url': 'https://api.github.com/repos/gatsbyjs/gatsby/hooks',
#   'issue_events_url': 'https://api.github.com/repos/gatsbyjs/gatsby/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/gatsbyjs/gatsby/events',
#   'assignees_url': 'https://api.github.com/repos/gatsbyjs/gatsby/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/gatsbyjs/gatsby/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/gatsbyjs/gatsby/tags',
#   'blobs_url': 'https://api.github.com/repos/gatsbyjs/gatsby/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/gatsbyjs/gatsby/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/gatsbyjs/gatsby/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/gatsbyjs/gatsby/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/gatsbyjs/gatsby/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/gatsbyjs/gatsby/languages',
#   'stargazers_url': 'https://api.github.com/repos/gatsbyjs/gatsby/stargazers',
#   'contributors_url': 'https://api.github.com/repos/gatsbyjs/gatsby/contributors',
#   'subscribers_url': 'https://api.github.com/repos/gatsbyjs/gatsby/subscribers',
#   'subscription_url': 'https://api.github.com/repos/gatsbyjs/gatsby/subscription',
#   'commits_url': 'https://api.github.com/repos/gatsbyjs/gatsby/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/gatsbyjs/gatsby/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/gatsbyjs/gatsby/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/gatsbyjs/gatsby/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/gatsbyjs/gatsby/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/gatsbyjs/gatsby/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/gatsbyjs/gatsby/merges',
#   'archive_url': 'https://api.github.com/repos/gatsbyjs/gatsby/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/gatsbyjs/gatsby/downloads',
#   'issues_url': 'https://api.github.com/repos/gatsbyjs/gatsby/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/gatsbyjs/gatsby/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/gatsbyjs/gatsby/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/gatsbyjs/gatsby/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/gatsbyjs/gatsby/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/gatsbyjs/gatsby/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/gatsbyjs/gatsby/deployments',
#   'created_at': '2015-05-21T22:43:05Z',
#   'updated_at': '2019-06-05T16:21:21Z',
#   'pushed_at': '2019-06-05T16:21:00Z',
#   'git_url': 'git://github.com/gatsbyjs/gatsby.git',
#   'ssh_url': 'git@github.com:gatsbyjs/gatsby.git',
#   'clone_url': 'https://github.com/gatsbyjs/gatsby.git',
#   'svn_url': 'https://github.com/gatsbyjs/gatsby',
#   'homepage': 'https://www.gatsbyjs.org',
#   'size': 559963,
#   'stargazers_count': 35284,
#   'watchers_count': 35284,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 5140,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 518,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 5140,
#   'open_issues': 518,
#   'watchers': 35284,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True}},
#  {'id': 52634092,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk1MjYzNDA5Mg==',
#   'name': 'control',
#   'full_name': 'supergiant/control',
#   'private': False,
#   'owner': {'login': 'supergiant',
#    'id': 17504253,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE3NTA0MjUz',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/17504253?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/supergiant',
#    'html_url': 'https://github.com/supergiant',
#    'followers_url': 'https://api.github.com/users/supergiant/followers',
#    'following_url': 'https://api.github.com/users/supergiant/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/supergiant/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/supergiant/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/supergiant/subscriptions',
#    'organizations_url': 'https://api.github.com/users/supergiant/orgs',
#    'repos_url': 'https://api.github.com/users/supergiant/repos',
#    'events_url': 'https://api.github.com/users/supergiant/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/supergiant/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/supergiant/control',
#   'description': 'Control manages the lifecycle of clusters on your infrastructure and allows deployment of applications via HELM. Its deployment and configuration workflows will help you to get up and running with Kubernetes faster.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/supergiant/control',
#   'forks_url': 'https://api.github.com/repos/supergiant/control/forks',
#   'keys_url': 'https://api.github.com/repos/supergiant/control/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/supergiant/control/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/supergiant/control/teams',
#   'hooks_url': 'https://api.github.com/repos/supergiant/control/hooks',
#   'issue_events_url': 'https://api.github.com/repos/supergiant/control/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/supergiant/control/events',
#   'assignees_url': 'https://api.github.com/repos/supergiant/control/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/supergiant/control/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/supergiant/control/tags',
#   'blobs_url': 'https://api.github.com/repos/supergiant/control/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/supergiant/control/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/supergiant/control/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/supergiant/control/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/supergiant/control/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/supergiant/control/languages',
#   'stargazers_url': 'https://api.github.com/repos/supergiant/control/stargazers',
#   'contributors_url': 'https://api.github.com/repos/supergiant/control/contributors',
#   'subscribers_url': 'https://api.github.com/repos/supergiant/control/subscribers',
#   'subscription_url': 'https://api.github.com/repos/supergiant/control/subscription',
#   'commits_url': 'https://api.github.com/repos/supergiant/control/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/supergiant/control/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/supergiant/control/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/supergiant/control/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/supergiant/control/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/supergiant/control/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/supergiant/control/merges',
#   'archive_url': 'https://api.github.com/repos/supergiant/control/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/supergiant/control/downloads',
#   'issues_url': 'https://api.github.com/repos/supergiant/control/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/supergiant/control/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/supergiant/control/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/supergiant/control/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/supergiant/control/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/supergiant/control/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/supergiant/control/deployments',
#   'created_at': '2016-02-26T21:32:33Z',
#   'updated_at': '2019-06-04T10:10:47Z',
#   'pushed_at': '2019-06-04T11:42:45Z',
#   'git_url': 'git://github.com/supergiant/control.git',
#   'ssh_url': 'git@github.com:supergiant/control.git',
#   'clone_url': 'https://github.com/supergiant/control.git',
#   'svn_url': 'https://github.com/supergiant/control',
#   'homepage': 'https://supergiant.io/toolkit/',
#   'size': 67517,
#   'stargazers_count': 666,
#   'watchers_count': 666,
#   'language': 'Go',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 60,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 48,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 60,
#   'open_issues': 48,
#   'watchers': 666,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True}},
#  {'id': 65219131,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2NTIxOTEzMQ==',
#   'name': 'learn-anything',
#   'full_name': 'learn-anything/learn-anything',
#   'private': False,
#   'owner': {'login': 'learn-anything',
#    'id': 28766659,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI4NzY2NjU5',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/28766659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/learn-anything',
#    'html_url': 'https://github.com/learn-anything',
#    'followers_url': 'https://api.github.com/users/learn-anything/followers',
#    'following_url': 'https://api.github.com/users/learn-anything/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/learn-anything/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/learn-anything/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/learn-anything/subscriptions',
#    'organizations_url': 'https://api.github.com/users/learn-anything/orgs',
#    'repos_url': 'https://api.github.com/users/learn-anything/repos',
#    'events_url': 'https://api.github.com/users/learn-anything/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/learn-anything/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/learn-anything/learn-anything',
#   'description': "Organize world's knowledge, explore connections and curate learning paths",
#   'fork': False,
#   'url': 'https://api.github.com/repos/learn-anything/learn-anything',
#   'forks_url': 'https://api.github.com/repos/learn-anything/learn-anything/forks',
#   'keys_url': 'https://api.github.com/repos/learn-anything/learn-anything/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/learn-anything/learn-anything/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/learn-anything/learn-anything/teams',
#   'hooks_url': 'https://api.github.com/repos/learn-anything/learn-anything/hooks',
#   'issue_events_url': 'https://api.github.com/repos/learn-anything/learn-anything/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/learn-anything/learn-anything/events',
#   'assignees_url': 'https://api.github.com/repos/learn-anything/learn-anything/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/learn-anything/learn-anything/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/learn-anything/learn-anything/tags',
#   'blobs_url': 'https://api.github.com/repos/learn-anything/learn-anything/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/learn-anything/learn-anything/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/learn-anything/learn-anything/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/learn-anything/learn-anything/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/learn-anything/learn-anything/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/learn-anything/learn-anything/languages',
#   'stargazers_url': 'https://api.github.com/repos/learn-anything/learn-anything/stargazers',
#   'contributors_url': 'https://api.github.com/repos/learn-anything/learn-anything/contributors',
#   'subscribers_url': 'https://api.github.com/repos/learn-anything/learn-anything/subscribers',
#   'subscription_url': 'https://api.github.com/repos/learn-anything/learn-anything/subscription',
#   'commits_url': 'https://api.github.com/repos/learn-anything/learn-anything/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/learn-anything/learn-anything/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/learn-anything/learn-anything/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/learn-anything/learn-anything/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/learn-anything/learn-anything/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/learn-anything/learn-anything/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/learn-anything/learn-anything/merges',
#   'archive_url': 'https://api.github.com/repos/learn-anything/learn-anything/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/learn-anything/learn-anything/downloads',
#   'issues_url': 'https://api.github.com/repos/learn-anything/learn-anything/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/learn-anything/learn-anything/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/learn-anything/learn-anything/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/learn-anything/learn-anything/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/learn-anything/learn-anything/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/learn-anything/learn-anything/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/learn-anything/learn-anything/deployments',
#   'created_at': '2016-08-08T16:09:17Z',
#   'updated_at': '2019-06-05T16:13:17Z',
#   'pushed_at': '2019-05-27T15:28:56Z',
#   'git_url': 'git://github.com/learn-anything/learn-anything.git',
#   'ssh_url': 'git@github.com:learn-anything/learn-anything.git',
#   'clone_url': 'https://github.com/learn-anything/learn-anything.git',
#   'svn_url': 'https://github.com/learn-anything/learn-anything',
#   'homepage': 'https://learn-anything.xyz',
#   'size': 56447,
#   'stargazers_count': 11262,
#   'watchers_count': 11262,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': True,
#   'forks_count': 723,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 723,
#   'open_issues': 0,
#   'watchers': 11262,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True}},
#  {'id': 97157866,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk5NzE1Nzg2Ng==',
#   'name': 'Time2Code',
#   'full_name': 'JockDaRock/Time2Code',
#   'private': False,
#   'owner': {'login': 'JockDaRock',
#    'id': 8311848,
#    'node_id': 'MDQ6VXNlcjgzMTE4NDg=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/8311848?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JockDaRock',
#    'html_url': 'https://github.com/JockDaRock',
#    'followers_url': 'https://api.github.com/users/JockDaRock/followers',
#    'following_url': 'https://api.github.com/users/JockDaRock/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JockDaRock/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JockDaRock/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JockDaRock/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JockDaRock/orgs',
#    'repos_url': 'https://api.github.com/users/JockDaRock/repos',
#    'events_url': 'https://api.github.com/users/JockDaRock/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JockDaRock/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JockDaRock/Time2Code',
#   'description': 'Portable Scalable web code editor to integrate into your sites and learning experiences',
#   'fork': False,
#   'url': 'https://api.github.com/repos/JockDaRock/Time2Code',
#   'forks_url': 'https://api.github.com/repos/JockDaRock/Time2Code/forks',
#   'keys_url': 'https://api.github.com/repos/JockDaRock/Time2Code/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JockDaRock/Time2Code/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JockDaRock/Time2Code/teams',
#   'hooks_url': 'https://api.github.com/repos/JockDaRock/Time2Code/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JockDaRock/Time2Code/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JockDaRock/Time2Code/events',
#   'assignees_url': 'https://api.github.com/repos/JockDaRock/Time2Code/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JockDaRock/Time2Code/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JockDaRock/Time2Code/tags',
#   'blobs_url': 'https://api.github.com/repos/JockDaRock/Time2Code/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JockDaRock/Time2Code/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JockDaRock/Time2Code/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JockDaRock/Time2Code/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JockDaRock/Time2Code/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/JockDaRock/Time2Code/languages',
#   'stargazers_url': 'https://api.github.com/repos/JockDaRock/Time2Code/stargazers',
#   'contributors_url': 'https://api.github.com/repos/JockDaRock/Time2Code/contributors',
#   'subscribers_url': 'https://api.github.com/repos/JockDaRock/Time2Code/subscribers',
#   'subscription_url': 'https://api.github.com/repos/JockDaRock/Time2Code/subscription',
#   'commits_url': 'https://api.github.com/repos/JockDaRock/Time2Code/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/JockDaRock/Time2Code/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/JockDaRock/Time2Code/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/JockDaRock/Time2Code/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/JockDaRock/Time2Code/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/JockDaRock/Time2Code/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/JockDaRock/Time2Code/merges',
#   'archive_url': 'https://api.github.com/repos/JockDaRock/Time2Code/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/JockDaRock/Time2Code/downloads',
#   'issues_url': 'https://api.github.com/repos/JockDaRock/Time2Code/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/JockDaRock/Time2Code/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/JockDaRock/Time2Code/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/JockDaRock/Time2Code/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/JockDaRock/Time2Code/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/JockDaRock/Time2Code/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/JockDaRock/Time2Code/deployments',
#   'created_at': '2017-07-13T19:27:59Z',
#   'updated_at': '2019-04-21T12:26:17Z',
#   'pushed_at': '2018-11-20T09:27:52Z',
#   'git_url': 'git://github.com/JockDaRock/Time2Code.git',
#   'ssh_url': 'git@github.com:JockDaRock/Time2Code.git',
#   'clone_url': 'https://github.com/JockDaRock/Time2Code.git',
#   'svn_url': 'https://github.com/JockDaRock/Time2Code',
#   'homepage': '',
#   'size': 1843,
#   'stargazers_count': 288,
#   'watchers_count': 288,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 26,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 6,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 26,
#   'open_issues': 6,
#   'watchers': 288,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True}},
#  {'id': 99143276,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk5OTE0MzI3Ng==',
#   'name': 'velero',
#   'full_name': 'heptio/velero',
#   'private': False,
#   'owner': {'login': 'heptio',
#    'id': 22035492,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMDM1NDky',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/22035492?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/heptio',
#    'html_url': 'https://github.com/heptio',
#    'followers_url': 'https://api.github.com/users/heptio/followers',
#    'following_url': 'https://api.github.com/users/heptio/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/heptio/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/heptio/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/heptio/subscriptions',
#    'organizations_url': 'https://api.github.com/users/heptio/orgs',
#    'repos_url': 'https://api.github.com/users/heptio/repos',
#    'events_url': 'https://api.github.com/users/heptio/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/heptio/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/heptio/velero',
#   'description': 'Backup and migrate Kubernetes applications and their persistent volumes',
#   'fork': False,
#   'url': 'https://api.github.com/repos/heptio/velero',
#   'forks_url': 'https://api.github.com/repos/heptio/velero/forks',
#   'keys_url': 'https://api.github.com/repos/heptio/velero/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/heptio/velero/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/heptio/velero/teams',
#   'hooks_url': 'https://api.github.com/repos/heptio/velero/hooks',
#   'issue_events_url': 'https://api.github.com/repos/heptio/velero/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/heptio/velero/events',
#   'assignees_url': 'https://api.github.com/repos/heptio/velero/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/heptio/velero/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/heptio/velero/tags',
#   'blobs_url': 'https://api.github.com/repos/heptio/velero/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/heptio/velero/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/heptio/velero/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/heptio/velero/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/heptio/velero/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/heptio/velero/languages',
#   'stargazers_url': 'https://api.github.com/repos/heptio/velero/stargazers',
#   'contributors_url': 'https://api.github.com/repos/heptio/velero/contributors',
#   'subscribers_url': 'https://api.github.com/repos/heptio/velero/subscribers',
#   'subscription_url': 'https://api.github.com/repos/heptio/velero/subscription',
#   'commits_url': 'https://api.github.com/repos/heptio/velero/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/heptio/velero/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/heptio/velero/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/heptio/velero/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/heptio/velero/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/heptio/velero/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/heptio/velero/merges',
#   'archive_url': 'https://api.github.com/repos/heptio/velero/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/heptio/velero/downloads',
#   'issues_url': 'https://api.github.com/repos/heptio/velero/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/heptio/velero/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/heptio/velero/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/heptio/velero/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/heptio/velero/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/heptio/velero/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/heptio/velero/deployments',
#   'created_at': '2017-08-02T17:22:11Z',
#   'updated_at': '2019-06-05T15:53:43Z',
#   'pushed_at': '2019-06-05T15:53:39Z',
#   'git_url': 'git://github.com/heptio/velero.git',
#   'ssh_url': 'git@github.com:heptio/velero.git',
#   'clone_url': 'https://github.com/heptio/velero.git',
#   'svn_url': 'https://github.com/heptio/velero',
#   'homepage': 'https://velero.io',
#   'size': 16390,
#   'stargazers_count': 2613,
#   'watchers_count': 2613,
#   'language': 'Go',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'forks_count': 401,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 190,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 401,
#   'open_issues': 190,
#   'watchers': 2613,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True}},
#  {'id': 36172821,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE3MjgyMQ==',
#   'name': 'embark',
#   'full_name': 'embark-framework/embark',
#   'private': False,
#   'owner': {'login': 'embark-framework',
#    'id': 12584440,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyNTg0NDQw',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/12584440?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/embark-framework',
#    'html_url': 'https://github.com/embark-framework',
#    'followers_url': 'https://api.github.com/users/embark-framework/followers',
#    'following_url': 'https://api.github.com/users/embark-framework/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/embark-framework/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/embark-framework/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/embark-framework/subscriptions',
#    'organizations_url': 'https://api.github.com/users/embark-framework/orgs',
#    'repos_url': 'https://api.github.com/users/embark-framework/repos',
#    'events_url': 'https://api.github.com/users/embark-framework/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/embark-framework/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/embark-framework/embark',
#   'description': 'Framework for serverless Decentralized Applications using Ethereum, IPFS and other platforms',
#   'fork': False,
#   'url': 'https://api.github.com/repos/embark-framework/embark',
#   'forks_url': 'https://api.github.com/repos/embark-framework/embark/forks',
#   'keys_url': 'https://api.github.com/repos/embark-framework/embark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/embark-framework/embark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/embark-framework/embark/teams',
#   'hooks_url': 'https://api.github.com/repos/embark-framework/embark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/embark-framework/embark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/embark-framework/embark/events',
#   'assignees_url': 'https://api.github.com/repos/embark-framework/embark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/embark-framework/embark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/embark-framework/embark/tags',
#   'blobs_url': 'https://api.github.com/repos/embark-framework/embark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/embark-framework/embark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/embark-framework/embark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/embark-framework/embark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/embark-framework/embark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/embark-framework/embark/languages',
#   'stargazers_url': 'https://api.github.com/repos/embark-framework/embark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/embark-framework/embark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/embark-framework/embark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/embark-framework/embark/subscription',
#   'commits_url': 'https://api.github.com/repos/embark-framework/embark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/embark-framework/embark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/embark-framework/embark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/embark-framework/embark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/embark-framework/embark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/embark-framework/embark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/embark-framework/embark/merges',
#   'archive_url': 'https://api.github.com/repos/embark-framework/embark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/embark-framework/embark/downloads',
# ...
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paimpozhil',
#    'html_url': 'https://github.com/paimpozhil',
#    'followers_url': 'https://api.github.com/users/paimpozhil/followers',
#    'following_url': 'https://api.github.com/users/paimpozhil/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paimpozhil/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paimpozhil/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paimpozhil/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paimpozhil/orgs',
#    'repos_url': 'https://api.github.com/users/paimpozhil/repos',
#    'events_url': 'https://api.github.com/users/paimpozhil/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paimpozhil/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/paimpozhil/docker-novnc',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/paimpozhil/docker-novnc',
#   'forks_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/forks',
#   'keys_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/teams',
#   'hooks_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/events',
#   'assignees_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/tags',
#   'blobs_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/languages',
#   'stargazers_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/subscription',
#   'commits_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/merges',
#   'archive_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/downloads',
#   'issues_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paimpozhil/docker-novnc/deployments',
#   'created_at': '2014-08-31T17:02:19Z',
#   'updated_at': '2019-05-23T08:06:10Z',
#   'pushed_at': '2015-05-18T21:07:00Z',
#   'git_url': 'git://github.com/paimpozhil/docker-novnc.git',
#   'ssh_url': 'git@github.com:paimpozhil/docker-novnc.git',
#   'clone_url': 'https://github.com/paimpozhil/docker-novnc.git',
#   'svn_url': 'https://github.com/paimpozhil/docker-novnc',
#   'homepage': None,
#   'size': 249,
#   'stargazers_count': 57,
#   'watchers_count': 57,
#   'language': 'Shell',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 25,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': None,
#   'forks': 25,
#   'open_issues': 4,
#   'watchers': 57,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True}},
#  {'id': 598164,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk1OTgxNjQ=',
#   'name': 'noVNC',
#   'full_name': 'novnc/noVNC',
#   'private': False,
#   'owner': {'login': 'novnc',
#    'id': 24572588,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NTcyNTg4',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/24572588?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/novnc',
#    'html_url': 'https://github.com/novnc',
#    'followers_url': 'https://api.github.com/users/novnc/followers',
#    'following_url': 'https://api.github.com/users/novnc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/novnc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/novnc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/novnc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/novnc/orgs',
#    'repos_url': 'https://api.github.com/users/novnc/repos',
#    'events_url': 'https://api.github.com/users/novnc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/novnc/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/novnc/noVNC',
#   'description': 'VNC client using HTML5 (WebSockets, Canvas)',
#   'fork': False,
#   'url': 'https://api.github.com/repos/novnc/noVNC',
#   'forks_url': 'https://api.github.com/repos/novnc/noVNC/forks',
#   'keys_url': 'https://api.github.com/repos/novnc/noVNC/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/novnc/noVNC/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/novnc/noVNC/teams',
#   'hooks_url': 'https://api.github.com/repos/novnc/noVNC/hooks',
#   'issue_events_url': 'https://api.github.com/repos/novnc/noVNC/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/novnc/noVNC/events',
#   'assignees_url': 'https://api.github.com/repos/novnc/noVNC/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/novnc/noVNC/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/novnc/noVNC/tags',
#   'blobs_url': 'https://api.github.com/repos/novnc/noVNC/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/novnc/noVNC/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/novnc/noVNC/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/novnc/noVNC/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/novnc/noVNC/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/novnc/noVNC/languages',
#   'stargazers_url': 'https://api.github.com/repos/novnc/noVNC/stargazers',
#   'contributors_url': 'https://api.github.com/repos/novnc/noVNC/contributors',
#   'subscribers_url': 'https://api.github.com/repos/novnc/noVNC/subscribers',
#   'subscription_url': 'https://api.github.com/repos/novnc/noVNC/subscription',
#   'commits_url': 'https://api.github.com/repos/novnc/noVNC/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/novnc/noVNC/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/novnc/noVNC/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/novnc/noVNC/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/novnc/noVNC/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/novnc/noVNC/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/novnc/noVNC/merges',
#   'archive_url': 'https://api.github.com/repos/novnc/noVNC/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/novnc/noVNC/downloads',
#   'issues_url': 'https://api.github.com/repos/novnc/noVNC/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/novnc/noVNC/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/novnc/noVNC/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/novnc/noVNC/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/novnc/noVNC/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/novnc/noVNC/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/novnc/noVNC/deployments',
#   'created_at': '2010-04-07T01:55:44Z',
#   'updated_at': '2019-06-05T13:50:22Z',
#   'pushed_at': '2019-05-25T00:52:27Z',
#   'git_url': 'git://github.com/novnc/noVNC.git',
#   'ssh_url': 'git@github.com:novnc/noVNC.git',
#   'clone_url': 'https://github.com/novnc/noVNC.git',
#   'svn_url': 'https://github.com/novnc/noVNC',
#   'homepage': 'https://novnc.com',
#   'size': 9547,
#   'stargazers_count': 5424,
#   'watchers_count': 5424,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1165,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 37,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'forks': 1165,
#   'open_issues': 37,
#   'watchers': 5424,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True}},
#  {'id': 77063495,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3NzA2MzQ5NQ==',
#   'name': 'ipyvolume',
#   'full_name': 'maartenbreddels/ipyvolume',
#   'private': False,
#   'owner': {'login': 'maartenbreddels',
#    'id': 1765949,
#    'node_id': 'MDQ6VXNlcjE3NjU5NDk=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/1765949?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/maartenbreddels',
#    'html_url': 'https://github.com/maartenbreddels',
#    'followers_url': 'https://api.github.com/users/maartenbreddels/followers',
#    'following_url': 'https://api.github.com/users/maartenbreddels/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/maartenbreddels/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/maartenbreddels/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/maartenbreddels/subscriptions',
#    'organizations_url': 'https://api.github.com/users/maartenbreddels/orgs',
#    'repos_url': 'https://api.github.com/users/maartenbreddels/repos',
#    'events_url': 'https://api.github.com/users/maartenbreddels/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/maartenbreddels/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/maartenbreddels/ipyvolume',
#   'description': '3d plotting for Python in the Jupyter notebook based on IPython widgets using WebGL',
#   'fork': False,
#   'url': 'https://api.github.com/repos/maartenbreddels/ipyvolume',
#   'forks_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/forks',
#   'keys_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/teams',
#   'hooks_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/hooks',
#   'issue_events_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/events',
#   'assignees_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/tags',
#   'blobs_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/languages',
#   'stargazers_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/stargazers',
#   'contributors_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/contributors',
#   'subscribers_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/subscribers',
#   'subscription_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/subscription',
#   'commits_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/merges',
#   'archive_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/downloads',
#   'issues_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/maartenbreddels/ipyvolume/deployments',
#   'created_at': '2016-12-21T15:30:13Z',
#   'updated_at': '2019-06-05T13:04:30Z',
#   'pushed_at': '2019-05-24T18:58:05Z',
#   'git_url': 'git://github.com/maartenbreddels/ipyvolume.git',
#   'ssh_url': 'git@github.com:maartenbreddels/ipyvolume.git',
#   'clone_url': 'https://github.com/maartenbreddels/ipyvolume.git',
#   'svn_url': 'https://github.com/maartenbreddels/ipyvolume',
#   'homepage': '',
#   'size': 54052,
#   'stargazers_count': 1141,
#   'watchers_count': 1141,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 141,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 98,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 141,
#   'open_issues': 98,
#   'watchers': 1141,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True}}]

# %%
response = requests.get("https://api.github.com/user", headers=headers)
user = response.json()

# %%
user
# Out:
# {'login': 'vishnoiprem',
#  'id': 5586954,
#  'node_id': 'MDQ6VXNlcjU1ODY5NTQ=',
#  'avatar_url': 'https://avatars2.githubusercontent.com/u/5586954?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/vishnoiprem',
#  'html_url': 'https://github.com/vishnoiprem',
#  'followers_url': 'https://api.github.com/users/vishnoiprem/followers',
#  'following_url': 'https://api.github.com/users/vishnoiprem/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/vishnoiprem/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/vishnoiprem/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/vishnoiprem/subscriptions',
#  'organizations_url': 'https://api.github.com/users/vishnoiprem/orgs',
#  'repos_url': 'https://api.github.com/users/vishnoiprem/repos',
#  'events_url': 'https://api.github.com/users/vishnoiprem/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/vishnoiprem/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'vishnoiprem',
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': True,
#  'bio': None,
#  'public_repos': 17,
#  'public_gists': 1,
#  'followers': 0,
#  'following': 3,
#  'created_at': '2013-10-01T15:27:46Z',
#  'updated_at': '2019-06-05T15:58:33Z',
#  'private_gists': 9,
#  'total_private_repos': 0,
#  'owned_private_repos': 0,
#  'disk_usage': 40101,
#  'collaborators': 0,
#  'two_factor_authentication': False,
#  'plan': {'name': 'free',
#   'space': 976562499,
#   'collaborators': 0,
#   'private_repos': 10000}}

# %%
payload = {"name": "test"}

# We need to pass in our authentication headers!
response = requests.post("https://api.github.com/user/repos", json=payload, headers=headers)
print(response.status_code)
# Out:
# 201

# %%
# Create the data we'll pass into the API endpoint.  While this endpoint only requires the "name" key, there are other optional keys.
payload = {"name": "test"}

# We need to pass in our authentication headers!
response = requests.post("https://api.github.com/user/repos", json=payload, headers=headers)
print(response.status_code)
payload = {"name": "learning-about-apis"}
response = requests.post("https://api.github.com/user/repos", json=payload, headers=headers)
status = response.status_code
# Out:
# 422

# %%
payload = {"description": "The best repository ever!", "name": "test"}
response = requests.patch("https://api.github.com/repos/VikParuchuri/test", json=payload, headers=headers)
print(response.status_code)
payload = {"description": "Learning about requests!", "name": "learning-about-apis"}
response = requests.patch("https://api.github.com/repos/VikParuchuri/learning-about-apis", json=payload, headers=headers)
status = response.status_code
# Out:
# 404

# %%
response = requests.delete("https://api.github.com/repos/VikParuchuri/test", headers=headers)
print(response.status_code)


response = requests.delete("https://api.github.com/repos/VikParuchuri/learning-about-apis", headers=headers)
status_code=response.status_code
# Out:
# 404
